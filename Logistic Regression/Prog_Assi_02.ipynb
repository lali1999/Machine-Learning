# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('Bank_Predictions.csv')
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
#printing the dataset
dataset
# Out:
#       Number  Customer_ID  Last_Name  Cr_Score Location  Gender  Age  History  \
# 0          1     15634602   Hargrave       619   France  Female   42        2
# 1          2     15647311       Hill       608    Spain  Female   41        1
# 2          3     15619304       Onio       502   France  Female   42        8
# 3          4     15701354       Boni       699   France  Female   39        1
# 4          5     15737888   Mitchell       850    Spain  Female   43        2
# ...      ...          ...        ...       ...      ...     ...  ...      ...
# 9995    9996     15606229   Obijiaku       771   France    Male   39        5
# 9996    9997     15569892  Johnstone       516   France    Male   35       10
# 9997    9998     15584532        Liu       709   France  Female   36        7
# 9998    9999     15682355  Sabbatini       772  Germany    Male   42        3
# 9999   10000     15628319     Walker       792   France  Female   28        4
#
# ...

# %%
# ------ Part-1: Data preprocessing ----------

# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

#encoding gender
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])

#encoding Location
location = ColumnTransformer([('encoder', OneHotEncoder(),[1])], remainder='passthrough')
X=np.array(location.fit_transform(X))
X = X[:, 1:]

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
# ------- Part-2: Build the ANN --------

# import keras library and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Initializing the ANN
classifier = Sequential()

# %%
# You might use the following parameters: activation: 'relu' and/or 'sigmoid'
# optimization function is 'adam', loss function is 'binary_crossentropy', number of epochs is 100, samples per epoch are 10)

# Adding the input layer and the first hidden layer
# The missing line of code here....

classifier.add(Dense(units=6, activation='relu', input_dim=len(X[0])))

# %%
# Adding second hidden layer
classifier.add(Dense(units=6, activation='relu'))

# %%
# Adding output layer
# The missing line of code here....
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# %%
# Compiling the ANN
classifier.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
# Fitting the ANN to the training set
classifier.fit(X_train, y_train, epochs=100, batch_size=10,validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4953 - accuracy: 0.7729 - val_loss: 0.4430 - val_accuracy: 0.7980
# Epoch 2/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4374 - accuracy: 0.8035 - val_loss: 0.4265 - val_accuracy: 0.8115
# Epoch 3/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4226 - accuracy: 0.8109 - val_loss: 0.4121 - val_accuracy: 0.8130
# Epoch 4/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4010 - accuracy: 0.8259 - val_loss: 0.3846 - val_accuracy: 0.8435
# Epoch 5/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3761 - accuracy: 0.8431 - val_loss: 0.3633 - val_accuracy: 0.8520
# Epoch 6/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3628 - accuracy: 0.8509 - val_loss: 0.3521 - val_accuracy: 0.8605
# Epoch 7/100
# ...

# %%
# Predicting the Test set results
# The missing line of code here....
y_predict = classifier.predict(X_test)
print(y_predict)

y_pred = (y_predict>0.5)
# Out:
# 63/63 [==============================] - 0s 1ms/step
# [[0.25763   ]
#  [0.2654751 ]
#  [0.14911333]
#  ...
#  [0.14342955]
#  [0.16596669]
#  [0.19187771]]

# %%
# Making the confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1501   94]
#  [ 196  209]]
